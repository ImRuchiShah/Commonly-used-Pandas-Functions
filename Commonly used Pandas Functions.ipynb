# %% [markdown]
# ### Commonly used Pandas Functions:
#
# Pandas is one of the most widely used libraries in the data science community and it’s a powerful tool that can help you with data manipulation, cleaning, and analysis.
#
# - pd.read_csv()
# - df.describe()
# - df.info()
# - df.plot()
# - df.iloc()
# - df.loc()
# - df.assign()
# - df.query()
# - df.sort_values()
# - df.sample()
# - df.isnull()
# - df.fillna()
# - df.dropna()
# - df.drop()
# - pd.pivot_table()
# - df.groupby()
# - df.transpose()
# - df.merge()
# - df.rename()
# - df.to_csv()

# %% [markdown]
# ### pd.read_csv()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/RUCHITA/Documents/Downloads/baby_names.csv')
df.head()
# Out:
#    brth_yr    gndr    ethcty         nm  cnt  rnk
# 0     2011  FEMALE  HISPANIC  GERALDINE   13   75
# 1     2011  FEMALE  HISPANIC        GIA   21   67
# 2     2011  FEMALE  HISPANIC     GIANNA   49   42
# 3     2011  FEMALE  HISPANIC    GISELLE   38   51
# 4     2011  FEMALE  HISPANIC      GRACE   36   53

# %% [markdown]
# ### df.describe()

# %%
print(df.describe())
# Out:
#             brth_yr           cnt           rnk
# count  13962.000000  13962.000000  13962.000000
# mean    2011.880318     34.531657     56.944349
# std        1.134940     40.176370     25.361691
# min     2011.000000     10.000000      1.000000
# 25%     2011.000000     13.000000     38.000000
# 50%     2011.000000     20.000000     59.000000
# 75%     2013.000000     36.000000     78.000000
# max     2014.000000    426.000000    102.000000

# %%
df.describe(include='all')
# Out:
#              brth_yr    gndr    ethcty     nm           cnt           rnk
# count   13962.000000   13962     13962  13962  13962.000000  13962.000000
# unique           NaN       2         7   2811           NaN           NaN
# top              NaN  FEMALE  HISPANIC  DYLAN           NaN           NaN
# freq             NaN    7139      4254     29           NaN           NaN
# mean     2011.880318     NaN       NaN    NaN     34.531657     56.944349
# std         1.134940     NaN       NaN    NaN     40.176370     25.361691
# min      2011.000000     NaN       NaN    NaN     10.000000      1.000000
# 25%      2011.000000     NaN       NaN    NaN     13.000000     38.000000
# 50%      2011.000000     NaN       NaN    NaN     20.000000     59.000000
# 75%      2013.000000     NaN       NaN    NaN     36.000000     78.000000
# max      2014.000000     NaN       NaN    NaN    426.000000    102.000000

# %%
df.describe(exclude='number') # exclude numerical columns
# Out:
#           gndr    ethcty     nm
# count    13962     13962  13962
# unique       2         7   2811
# top     FEMALE  HISPANIC  DYLAN
# freq      7139      4254     29

# %% [markdown]
# ### df.info()
#
# df.info() is a method in pandas that is used to get a concise summary of the DataFrame, including the number of non-null values in each column, the data types of each column, and the memory usage of the DataFrame.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13962 entries, 0 to 13961
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   brth_yr  13962 non-null  int64
#  1   gndr     13962 non-null  object
#  2   ethcty   13962 non-null  object
#  3   nm       13962 non-null  object
#  4   cnt      13962 non-null  int64
#  5   rnk      13962 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 654.6+ KB
# None

# %% [markdown]
# ### df.plot()

# %%
df['gndr'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### df.iloc()
# Pandas’ .iloc() function is used to select rows and columns by their integer-based index in a DataFrame. It is used to select rows and columns by their integer-based location.

# %%
# Select the first row
print(df.iloc[0])
# Out:
# brth_yr         2011
# gndr          FEMALE
# ethcty      HISPANIC
# nm         GERALDINE
# cnt               13
# rnk               75
# Name: 0, dtype: object

# %%
# Select the first two rows
print(df.iloc[:2])
# Out:
#    brth_yr    gndr    ethcty         nm  cnt  rnk
# 0     2011  FEMALE  HISPANIC  GERALDINE   13   75
# 1     2011  FEMALE  HISPANIC        GIA   21   67

# %%
# Select the first column
print(df.iloc[:, 0])
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 13957    2014
# 13958    2014
# 13959    2014
# 13960    2014
# 13961    2014
# Name: brth_yr, Length: 13962, dtype: int64

# %%
# Select the first two columns
print(df.iloc[:, :2])
# Out:
#        brth_yr    gndr
# 0         2011  FEMALE
# 1         2011  FEMALE
# 2         2011  FEMALE
# 3         2011  FEMALE
# 4         2011  FEMALE
# ...        ...     ...
# 13957     2014    MALE
# 13958     2014    MALE
# 13959     2014    MALE
# 13960     2014    MALE
# 13961     2014    MALE
#
# [13962 rows x 2 columns]

# %%
# Select the (1, 1) element
print(df.iloc[1, 1])
# Out:
# FEMALE

# %% [markdown]
# ### df.loc()
# Pandas’ .loc() function is used to select rows and columns by their label-based index in a DataFrame. It is used to select rows and columns by their label-based location.

# %%
# Select the column name 'Gender'
print(df.loc[:,'gndr'])
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 13957      MALE
# 13958      MALE
# 13959      MALE
# 13960      MALE
# 13961      MALE
# Name: gndr, Length: 13962, dtype: object

# %%
# Select the columns named 'Year of Birth' and 'Gender'
print(df.loc[:, ['brth_yr', 'gndr']])
# Out:
#        brth_yr    gndr
# 0         2011  FEMALE
# 1         2011  FEMALE
# 2         2011  FEMALE
# 3         2011  FEMALE
# 4         2011  FEMALE
# ...        ...     ...
# 13957     2014    MALE
# 13958     2014    MALE
# 13959     2014    MALE
# 13960     2014    MALE
# 13961     2014    MALE
#
# [13962 rows x 2 columns]

# %% [markdown]
# ### df.assign()
# Pandas’ .assign() function is used to add new columns to a DataFrame, based on the computation of existing columns. It allows you to add new columns to a DataFrame without modifying the original dataframe. The function returns a new DataFrame with the added columns.

# %%
df_new = df.assign(count_plus_5=df['cnt'] + 5)
df_new.head()
# Out:
#    brth_yr    gndr    ethcty         nm  cnt  rnk  count_plus_5
# 0     2011  FEMALE  HISPANIC  GERALDINE   13   75            18
# 1     2011  FEMALE  HISPANIC        GIA   21   67            26
# 2     2011  FEMALE  HISPANIC     GIANNA   49   42            54
# 3     2011  FEMALE  HISPANIC    GISELLE   38   51            43
# 4     2011  FEMALE  HISPANIC      GRACE   36   53            41

# %% [markdown]
# ### df.query()
# Pandas’ .query() function allows you to filter a DataFrame based on a Boolean expression. It allows you to select rows from a DataFrame using a query string similar to SQL. The function returns a new DataFrame containing only the rows that satisfy the Boolean expression.

# %%
# Select rows where age is greater than 30 and income is less than 65000
df_query = df.query('cnt > 30 and rnk < 20')
df_query.head()
# Out:
#      brth_yr    gndr    ethcty        nm  cnt  rnk
# 6       2011  FEMALE  HISPANIC    HAILEY  126    8
# 22      2011  FEMALE  HISPANIC  ISABELLA  331    1
# 81      2011  FEMALE  HISPANIC  KIMBERLY  103   13
# 90      2011  FEMALE  HISPANIC      LEAH  123    9
# 109     2011  FEMALE  HISPANIC   MADISON  122   10

# %%
# Select rows where gender is Male
df_query = df.query("gndr == 'MALE'")
df_query.head()
# Out:
#      brth_yr  gndr                      ethcty        nm  cnt  rnk
# 546     2011  MALE  ASIAN AND PACIFIC ISLANDER     AARAV   15   51
# 547     2011  MALE  ASIAN AND PACIFIC ISLANDER     AARON   51   19
# 548     2011  MALE  ASIAN AND PACIFIC ISLANDER     ABDUL   20   46
# 549     2011  MALE  ASIAN AND PACIFIC ISLANDER  ABDULLAH   30   36
# 550     2011  MALE  ASIAN AND PACIFIC ISLANDER      ADAM   28   38

# %% [markdown]
# ### df.sort_values()
# Pandas’ .sort_values() function allows you to sort a DataFrame by one or multiple columns. It sorts the DataFrame based on the values of one or more columns, in ascending or descending order. The function returns a new DataFrame sorted by the specified column(s).

# %%
# Sort by age in ascending order
df_sorted = df.sort_values(by='cnt')
df_sorted.head()
# Out:
#        brth_yr    gndr                      ethcty          nm  cnt  rnk
# 8744      2012  FEMALE              WHITE NON HISP         MAE   10   83
# 6746      2011  FEMALE          WHITE NON HISPANIC       LEILA   10   81
# 2389      2011    MALE                    HISPANIC       ALLAN   10   94
# 11009     2013    MALE  ASIAN AND PACIFIC ISLANDER      Martin   10   57
# 11013     2013    MALE  ASIAN AND PACIFIC ISLANDER  Maximilian   10   57

# %%
# Sort by income in descending order
df_sorted = df.sort_values(by='rnk', ascending=False)
df_sorted.head()
# Out:
#        brth_yr  gndr              ethcty        nm  cnt  rnk
# 13719     2014  MALE  WHITE NON HISPANIC      Erik   10  102
# 13844     2014  MALE  WHITE NON HISPANIC   Mordche   10  102
# 13760     2014  MALE  WHITE NON HISPANIC     Issac   10  102
# 13691     2014  MALE  WHITE NON HISPANIC  Dashiell   10  102
# 13757     2014  MALE  WHITE NON HISPANIC     Imran   10  102

# %%
# Sort by multiple columns
df_sorted = df.sort_values(by=['cnt', 'rnk'])
df_sorted.head()
# Out:
#      brth_yr    gndr                      ethcty         nm  cnt  rnk
# 957     2011  FEMALE  ASIAN AND PACIFIC ISLANDER       AIZA   10   38
# 959     2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALEXA   10   38
# 963     2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALISHA   10   38
# 974     2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ANGIE   10   38
# 977     2011  FEMALE  ASIAN AND PACIFIC ISLANDER  ANNABELLE   10   38

# %% [markdown]
# ### df.sample()
# Pandas’ .sample() function allows you to randomly select rows from a DataFrame. It returns a new DataFrame containing the randomly selected rows. The function takes several parameters that allow you to control the sampling process, such as the number of rows to return, and whether or not to sample with replacement and seed for reproducibility.

# %%
# Sample 2 rows without replacement
df_sample = df.sample(n=2, replace=False, random_state=1)
df_sample
# Out:
#        brth_yr    gndr              ethcty      nm  cnt  rnk
# 5258      2011    MALE  BLACK NON HISPANIC  SAMUEL   30   44
# 10812     2013  FEMALE  WHITE NON HISPANIC   Raizy   65   33

# %%
# Sample 3 rows with replacement
df_sample = df.sample(n=3, replace=True, random_state=1)
df_sample
# Out:
#        brth_yr    gndr              ethcty      nm  cnt  rnk
# 13349     2014    MALE            HISPANIC  Andres   30   78
# 235       2011  FEMALE  WHITE NON HISPANIC    ANNA   85   25
# 12172     2014  FEMALE  BLACK NON HISPANIC    Kyla   11   40

# %%
# Sample 2 rows without replacement with specific column to be chosen
df_sample = df.sample(n=2, replace=False, random_state=1, axis=1)
df_sample
# Out:
#                    ethcty    gndr
# 0                HISPANIC  FEMALE
# 1                HISPANIC  FEMALE
# 2                HISPANIC  FEMALE
# 3                HISPANIC  FEMALE
# 4                HISPANIC  FEMALE
# ...                   ...     ...
# 13957  WHITE NON HISPANIC    MALE
# 13958  WHITE NON HISPANIC    MALE
# 13959  WHITE NON HISPANIC    MALE
# 13960  WHITE NON HISPANIC    MALE
# 13961  WHITE NON HISPANIC    MALE
#
# [13962 rows x 2 columns]

# %% [markdown]
# ### df.isnull()

# %%
df.isnull()
# Out:
#        brth_yr   gndr  ethcty     nm    cnt    rnk
# 0        False  False   False  False  False  False
# 1        False  False   False  False  False  False
# 2        False  False   False  False  False  False
# 3        False  False   False  False  False  False
# 4        False  False   False  False  False  False
# ...        ...    ...     ...    ...    ...    ...
# 13957    False  False   False  False  False  False
# 13958    False  False   False  False  False  False
# 13959    False  False   False  False  False  False
# 13960    False  False   False  False  False  False
# 13961    False  False   False  False  False  False
#
# [13962 rows x 6 columns]

# %% [markdown]
# ### df.fillna()

# %%
# fill missing values with 0
df.fillna(0)

# forward-fill missing values (propagates last valid observation forward to next)
df.fillna(method='ffill')

# backward-fill missing values (propagates next valid observation backward to last)
df.fillna(method='bfill')

# fill missing values using interpolation
df.interpolate()
# Out:
#        brth_yr    gndr              ethcty         nm  cnt  rnk
# 0         2011  FEMALE            HISPANIC  GERALDINE   13   75
# 1         2011  FEMALE            HISPANIC        GIA   21   67
# 2         2011  FEMALE            HISPANIC     GIANNA   49   42
# 3         2011  FEMALE            HISPANIC    GISELLE   38   51
# 4         2011  FEMALE            HISPANIC      GRACE   36   53
# ...        ...     ...                 ...        ...  ...  ...
# 13957     2014    MALE  WHITE NON HISPANIC     Yousef   18   94
# 13958     2014    MALE  WHITE NON HISPANIC    Youssef   24   88
# 13959     2014    MALE  WHITE NON HISPANIC      Yusuf   16   96
# 13960     2014    MALE  WHITE NON HISPANIC    Zachary   90   39
# 13961     2014    MALE  WHITE NON HISPANIC        Zev   49   65
#
# [13962 rows x 6 columns]

# %%
# fill missing values in place
df.fillna(0, inplace=True)

# %% [markdown]
# ### df.dropna()

# %%
# You can remove all rows containing at least one missing value by calling df.dropna().
df = df.dropna()

# %%
# If you want to remove only the columns that contain at least one missing value you can use df.dropna(axis=1)
df = df.dropna(axis=1)

# %%
# You can also set thresh parameter to keep only the rows/columns that have at least thresh non-NA/null values.
df = df.dropna(thresh=2)

# %% [markdown]
# ### df.drop()
# df.drop() is a method used in the Pandas library to remove rows or columns from a DataFrame by specifying the corresponding labels. It can be used to drop one or multiple rows or columns based on their labels.
#
# You can remove a specific row by calling df.drop() and passing the index label of the row you want to remove, and the axis parameter set to 0 (default is 0)

# %%
# remove the first row of the DataFrame.
df_drop = df.drop(0)

# %%
# drop multiple rows by passing a list of index labels
df_drop = df.drop([0,1])

# %%
# drop columns by passing the labels of the columns you want to remove and setting the axis parameter to 1:

df_drop = df.drop(['cnt', 'rnk'], axis=1)

# %% [markdown]
# ### pd.pivot_table()
#
# pd.pivot_table() is a method in the Pandas library that is used to create a pivot table from a DataFrame. A pivot table is a table that summarizes and aggregates data in a more meaningful and organized way, by creating a new table with one or more columns as the index, one or more columns as values, and one or more columns as attributes.

# %%
pivot_table = pd.pivot_table(df, index='ethcty', values='cnt', aggfunc='sum')
pivot_table.head()
# Out:
#                                cnt
# ethcty
# ASIAN AND PACI               10300
# ASIAN AND PACIFIC ISLANDER   51379
# BLACK NON HISP               10208
# BLACK NON HISPANIC           62265
# HISPANIC                    167237

# %%
pivot_table = pd.pivot_table(df, index=['ethcty','gndr'], values= 'cnt' , aggfunc=['sum','count'])
pivot_table.head(20)
# Out:
#                                      sum count
#                                      cnt   cnt
# ethcty                     gndr
# ASIAN AND PACI             FEMALE   4338   179
#                            MALE     5962   179
# ASIAN AND PACIFIC ISLANDER FEMALE  21882   984
#                            MALE    29497   968
# BLACK NON HISP             FEMALE   4243   171
#                            MALE     5965   182
# BLACK NON HISPANIC         FEMALE  26157  1104
#                            MALE    36108  1170
# HISPANIC                   FEMALE  70754  2205
#                            MALE    96483  2049
# WHITE NON HISP             FEMALE  12402   371
#                            MALE    14273   330
# WHITE NON HISPANIC         FEMALE  70307  2125
#                            MALE    83760  1945

# %% [markdown]
# ### df.groupby()
#
# df.groupby() is a method in the Pandas library that is used to group rows of a DataFrame based on one or multiple columns. This allows you to perform aggregate operations on the groups, such as calculating the mean, sum, or count of the values in each group.
#
# df.groupby() returns a GroupBy object, which you can then use to perform various operations on the groups, such as calculating the sum, mean, or count of the values in each group.

# %%
grouped = df.groupby('gndr')
# Print the mean of each group
print(grouped.mean())
# Out:
#             brth_yr        cnt        rnk
# gndr
# FEMALE  2011.881356  29.427511  51.859224
# MALE    2011.879232  39.872197  62.264986

# %%
grouped = df.groupby(['gndr', 'ethcty'])

# Print the sum of each group
print(grouped.sum())
# Out:
#                                    brth_yr    cnt     rnk
# gndr   ethcty
# FEMALE ASIAN AND PACI               360148   4338    5977
#        ASIAN AND PACIFIC ISLANDER  1979729  21882   28616
#        BLACK NON HISP               344052   4243    5806
#        BLACK NON HISPANIC          2221067  26157   35908
#        HISPANIC                    4436074  70754  133141
#        WHITE NON HISP               746452  12402   24155
#        WHITE NON HISPANIC          4275299  70307  136620
# MALE   ASIAN AND PACI               360148   5962    7846
#        ASIAN AND PACIFIC ISLANDER  1947565  29497   39511
#        BLACK NON HISP               366184   5965    7927
#        BLACK NON HISPANIC          2353793  36108   55404
#        HISPANIC                    4122280  96483  146055
#        WHITE NON HISP               663960  14273   23285
#        WHITE NON HISPANIC          3913122  83760  144806

# %% [markdown]
# ### df.transpose()

# %%
# Transpose the DataFrame
df_transposed = df.transpose()

# Print the transposed DataFrame
df_transposed.head()
# Out:
#              0         1         2         3         4          5      \
# brth_yr       2011      2011      2011      2011      2011       2011
# gndr        FEMALE    FEMALE    FEMALE    FEMALE    FEMALE     FEMALE
# ethcty    HISPANIC  HISPANIC  HISPANIC  HISPANIC  HISPANIC   HISPANIC
# nm       GERALDINE       GIA    GIANNA   GISELLE     GRACE  GUADALUPE
# cnt             13        21        49        38        36         26
#
#             6         7         8         9      ...               13952  \
# brth_yr      2011      2011      2011      2011  ...                2014
# gndr       FEMALE    FEMALE    FEMALE    FEMALE  ...                MALE
# ethcty   HISPANIC  HISPANIC  HISPANIC  HISPANIC  ...  WHITE NON HISPANIC
# nm         HAILEY     HALEY    HANNAH    HAYLEE  ...            Yitzchak
# cnt           126        14        17        17  ...                  15
#
#                       13953               13954               13955  \
# brth_yr                2014                2014                2014
# gndr                   MALE                MALE                MALE
# ethcty   WHITE NON HISPANIC  WHITE NON HISPANIC  WHITE NON HISPANIC
# nm                 Yitzchok                Yoel               Yosef
# cnt                      66                  12                 116
#
#                       13956               13957               13958  \
# brth_yr                2014                2014                2014
# gndr                   MALE                MALE                MALE
# ethcty   WHITE NON HISPANIC  WHITE NON HISPANIC  WHITE NON HISPANIC
# nm                    Yossi              Yousef             Youssef
# cnt                      15                  18                  24
#
#                       13959               13960               13961
# brth_yr                2014                2014                2014
# gndr                   MALE                MALE                MALE
# ethcty   WHITE NON HISPANIC  WHITE NON HISPANIC  WHITE NON HISPANIC
# nm                    Yusuf             Zachary                 Zev
# cnt                      16                  90                  49
#
# [5 rows x 13962 columns]

# %%
# It can also be done using T attributes on the dataframe. df.T will do the same as df.transpose().

df_transposed = df.T
df_transposed.head()
# Out:
#              0         1         2         3         4          5      \
# brth_yr       2011      2011      2011      2011      2011       2011
# gndr        FEMALE    FEMALE    FEMALE    FEMALE    FEMALE     FEMALE
# ethcty    HISPANIC  HISPANIC  HISPANIC  HISPANIC  HISPANIC   HISPANIC
# nm       GERALDINE       GIA    GIANNA   GISELLE     GRACE  GUADALUPE
# cnt             13        21        49        38        36         26
#
#             6         7         8         9      ...               13952  \
# brth_yr      2011      2011      2011      2011  ...                2014
# gndr       FEMALE    FEMALE    FEMALE    FEMALE  ...                MALE
# ethcty   HISPANIC  HISPANIC  HISPANIC  HISPANIC  ...  WHITE NON HISPANIC
# nm         HAILEY     HALEY    HANNAH    HAYLEE  ...            Yitzchak
# cnt           126        14        17        17  ...                  15
#
#                       13953               13954               13955  \
# brth_yr                2014                2014                2014
# gndr                   MALE                MALE                MALE
# ethcty   WHITE NON HISPANIC  WHITE NON HISPANIC  WHITE NON HISPANIC
# nm                 Yitzchok                Yoel               Yosef
# cnt                      66                  12                 116
#
#                       13956               13957               13958  \
# brth_yr                2014                2014                2014
# gndr                   MALE                MALE                MALE
# ethcty   WHITE NON HISPANIC  WHITE NON HISPANIC  WHITE NON HISPANIC
# nm                    Yossi              Yousef             Youssef
# cnt                      15                  18                  24
#
#                       13959               13960               13961
# brth_yr                2014                2014                2014
# gndr                   MALE                MALE                MALE
# ethcty   WHITE NON HISPANIC  WHITE NON HISPANIC  WHITE NON HISPANIC
# nm                    Yusuf             Zachary                 Zev
# cnt                      16                  90                  49
#
# [5 rows x 13962 columns]

# %% [markdown]
# ### df.merge()

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key')

# Print the merged DataFrame
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %% [markdown]
# #You can also merge multiple columns by passing a list of columns to the on parameter.
#
# merged_df = df1.merge(df2, on=['key1','key2'])
#
# #You can also specify a different column name to merge by using left_on and right_on parameters.
#
# merged_df = df1.merge(df2, left_on='key1', right_on='key3')

# %% [markdown]
# ### df.rename()

# %%
# Rename column 'Count' to 'count'
df_rename = df.rename(columns={'cnt': 'count'})
df_rename.head()
# Out:
#    brth_yr    gndr    ethcty         nm  count  rnk
# 0     2011  FEMALE  HISPANIC  GERALDINE     13   75
# 1     2011  FEMALE  HISPANIC        GIA     21   67
# 2     2011  FEMALE  HISPANIC     GIANNA     49   42
# 3     2011  FEMALE  HISPANIC    GISELLE     38   51
# 4     2011  FEMALE  HISPANIC      GRACE     36   53

# %%
#You can also use a dictionary to rename multiple columns at once:

df_rename = df.rename(columns={'count': 'Count', 'rnk':'rank'})
df_rename.head()
# Out:
#    brth_yr    gndr    ethcty         nm  cnt  rank
# 0     2011  FEMALE  HISPANIC  GERALDINE   13    75
# 1     2011  FEMALE  HISPANIC        GIA   21    67
# 2     2011  FEMALE  HISPANIC     GIANNA   49    42
# 3     2011  FEMALE  HISPANIC    GISELLE   38    51
# 4     2011  FEMALE  HISPANIC      GRACE   36    53

# %%
#You can also rename the index similarly:

df_rename = df.rename(index={0:'first',1:'second',2:'third'})
df_rename.head()
# Out:
#         brth_yr    gndr    ethcty         nm  cnt  rnk
# first      2011  FEMALE  HISPANIC  GERALDINE   13   75
# second     2011  FEMALE  HISPANIC        GIA   21   67
# third      2011  FEMALE  HISPANIC     GIANNA   49   42
# 3          2011  FEMALE  HISPANIC    GISELLE   38   51
# 4          2011  FEMALE  HISPANIC      GRACE   36   53

# %% [markdown]
# ### df.to_csv()
#
# df.to_csv() is a method used in the Pandas library to export a DataFrame to a CSV file. CSV stands for "Comma Separated Values" and it is a popular file format for storing data in a tabular form.
#
# For example, let’s say we want to save df that you want to export to a CSV file. You can export the DataFrame to a CSV file by calling df.to_csv() and passing the file name as a string:

# %%
df.to_csv('data.csv')

# %% [markdown]
# This will save the DataFrame to a file named data.csv in the current working directory. You can also specify the path of the file by passing it to the method:
#
# #### df.to_csv('path/to/data.csv')
#
# You can also specify the separator used in the CSV file by passing the sep parameter. By default, it’s set to “,”.
#
# #### df.to_csv('path/to/data.csv', sep='\t')
#
# It is also possible to only save specific columns of the DataFrame by passing the list of column names to the columns parameter, and also to save only specific rows by passing a boolean mask to the index parameter.
#
# #### df.to_csv('path/to/data.csv', columns=['Rank','Count'])
# You can also use the index parameter to specify whether to include or exclude the index of the dataframe in the exported CSV file.
#
# #### df.to_csv('path/to/data.csv', index=False)
# This will exclude the index of the dataframe in the exported CSV file.
#
# You can also use na_rep parameter to replace missing values in the exported CSV file with a specific value.
#
# #### df.to_csv('path/to/data.csv', na_rep='NULL')
